# %% [markdown]
# # Visualizing MNIST using t-SNE
#
# The objective of this Notebook is to visualize the MNIST data set in two and three dimensions, using the projection onto this lower dimensional spaces given by the technique t-SNE.

# %%
#Imports and a little bit of setup
from __future__ import print_function
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from mnist import MNIST
import math

# import jtplot submodule from jupyterthemes
from jupyterthemes import jtplot

# currently installed theme will be used to
# set plot style if no arguments providedb
#jtplot.style(theme = 'default')
jtplot.style()

#A little bit of matplotlib magic so that the images can be showed on the IPython notebook
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

#Small function that helps displays images
def imshow_noax(img, normalize=True):
    """ Tiny helper to show images as uint8 and remove axis labels """
    if normalize:
        img_max, img_min = np.max(img), np.min(img)
        img = 255.0 * (img - img_min) / (img_max - img_min)
    plt.imshow(img.astype('uint8'))
    plt.gca().axis('off')

# %%
#Imports the data and converts it to numpy arrays
mndata = MNIST('../python-mnist/data')
X, labels = mndata.load_testing()

#converts to numpy array
X = np.array(X)
labels = np.array(labels)

subsample_idices = np.random.choice(X.shape[0], 5000)
X = X[subsample_idices,:]
labels = labels[subsample_idices]

#Converts to binary the selcted sample
X = np.around(1-(X/255))

N, D = X.shape

#Declares the cmap for coloring
#COlors
selected_colors = ['red','greenyellow','blue','pink','yellow','orange',
                   'lightcyan','darkolivegreen', 'brown','purple']
cmap = plt.cm.jet
# create the new map
cmap = cmap.from_list('Custom cmap', selected_colors, 10)

# %%
#Imports the data and converts it to numpy arrays
mndata = MNIST('../python-mnist/data')
X, labels = mndata.load_testing()

#converts to numpy array
X = np.array(X)
labels = np.array(labels)

X = X[np.isin(labels,[1,2,3]),]
labels = labels[np.isin(labels,[1,2,3]),]

#Converts to binary the selcted sample
X = np.around(1-(X/255))

N, D = X.shape

#Declares the cmap for coloring
#COlors
selected_colors = ['red','greenyellow','blue','pink','yellow','orange',
                   'lightcyan','darkolivegreen', 'brown','purple']
cmap = plt.cm.jet
# create the new map
cmap = cmap.from_list('Custom cmap', selected_colors, 10)

X.shape
# Out:
# (3177, 784)

# %% [markdown]
# # t-SNE
#
# This authors of this technique offer a free python implementation on their website: *https://lvdmaaten.github.io/tsne/*. The script was downloaded and is imported into this notebook (some small syntax changes where made for it to run on python3)

# %%
from tsne import *

# %% [markdown]
# ### Two Dimensional t-SNE

# %%
#runs t-SNE
#2 dimensions
Y = tsne(X, 2, 50, 20.0);
# Out:
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point  0  of  3177 ...
# Computing P-values for point  500  of  3177 ...
# Computing P-values for point  1000  of  3177 ...
# Computing P-values for point  1500  of  3177 ...
# Computing P-values for point  2000  of  3177 ...
# Computing P-values for point  2500  of  3177 ...
# Computing P-values for point  3000  of  3177 ...
# Mean value of sigma:  1.81171598993
# Iteration  10 : error is  24.8248814318
# Iteration  20 : error is  23.0189924036
# Iteration  30 : error is  19.9507348556
# Iteration  40 : error is  18.7712307741
# Iteration  50 : error is  18.3985943038
# Iteration  60 : error is  18.2898532332
# Iteration  70 : error is  18.1948783195
# Iteration  80 : error is  17.9715635883
# Iteration  90 : error is  17.8288994834
# Iteration  100 : error is  17.7566937397
# Iteration  110 : error is  2.70659436069
# Iteration  120 : error is  2.48668093626
# Iteration  130 : error is  2.30852862159
# Iteration  140 : error is  2.16265014011
# Iteration  150 : error is  2.04385256908
# Iteration  160 : error is  1.94733979742
# Iteration  170 : error is  1.86858577301
# Iteration  180 : error is  1.80323049445
# Iteration  190 : error is  1.74831360198
# Iteration  200 : error is  1.70159496209
# Iteration  210 : error is  1.66132421862
# Iteration  220 : error is  1.62638019869
# Iteration  230 : error is  1.59590254049
# Iteration  240 : error is  1.56918117285
# Iteration  250 : error is  1.54548002716
# Iteration  260 : error is  1.52440049925
# Iteration  270 : error is  1.50556782783
# Iteration  280 : error is  1.48857559897
# Iteration  290 : error is  1.47322674503
# Iteration  300 : error is  1.4592423626
# Iteration  310 : error is  1.44657873292
# Iteration  320 : error is  1.43497552744
# Iteration  330 : error is  1.42442086719
# Iteration  340 : error is  1.41474694614
# Iteration  350 : error is  1.40578366002
# Iteration  360 : error is  1.39745861861
# Iteration  370 : error is  1.38971159046
# Iteration  380 : error is  1.38246279274
# Iteration  390 : error is  1.37574704278
# Iteration  400 : error is  1.36946559529
# Iteration  410 : error is  1.36359607553
# Iteration  420 : error is  1.3581089041
# Iteration  430 : error is  1.35293098881
# Iteration  440 : error is  1.34804111942
# Iteration  450 : error is  1.34342800431
# Iteration  460 : error is  1.3390686684
# Iteration  470 : error is  1.33493833182
# Iteration  480 : error is  1.33101929423
# Iteration  490 : error is  1.32731358806
# Iteration  500 : error is  1.32380796088
# Iteration  510 : error is  1.32048237949
# Iteration  520 : error is  1.31731935277
# Iteration  530 : error is  1.3142958349
# Iteration  540 : error is  1.31140455601
# Iteration  550 : error is  1.30864193916
# Iteration  560 : error is  1.30600133493
# Iteration  570 : error is  1.30347849567
# Iteration  580 : error is  1.30107506075
# Iteration  590 : error is  1.29878976767
# Iteration  600 : error is  1.29660409468
# Iteration  610 : error is  1.29450652063
# Iteration  620 : error is  1.29247101607
# Iteration  630 : error is  1.290526261
# Iteration  640 : error is  1.28867939185
# Iteration  650 : error is  1.2869121272
# Iteration  660 : error is  1.28521299899
# Iteration  670 : error is  1.28357547754
# Iteration  680 : error is  1.28199541248
# Iteration  690 : error is  1.28047376572
# Iteration  700 : error is  1.2790113126
# Iteration  710 : error is  1.2776024272
# Iteration  720 : error is  1.2762441458
# Iteration  730 : error is  1.27493180429
# Iteration  740 : error is  1.27366086192
# Iteration  750 : error is  1.27243059961
# Iteration  760 : error is  1.27124030082
# Iteration  770 : error is  1.2700880435
# Iteration  780 : error is  1.26897375256
# Iteration  790 : error is  1.26789650329
# Iteration  800 : error is  1.26685351439
# Iteration  810 : error is  1.26584211143
# Iteration  820 : error is  1.26486212213
# Iteration  830 : error is  1.26391375268
# Iteration  840 : error is  1.26299687346
# Iteration  850 : error is  1.26210745526
# Iteration  860 : error is  1.26124421911
# Iteration  870 : error is  1.26040401178
# Iteration  880 : error is  1.25958548045
# Iteration  890 : error is  1.2587863604
# Iteration  900 : error is  1.25800658917
# Iteration  910 : error is  1.25724433044
# Iteration  920 : error is  1.25649747491
# Iteration  930 : error is  1.25577358401
# Iteration  940 : error is  1.25507380966
# Iteration  950 : error is  1.25439528944
# Iteration  960 : error is  1.25373441575
# Iteration  970 : error is  1.25309107374
# Iteration  980 : error is  1.25246412651
# Iteration  990 : error is  1.25185455828
# Iteration  1000 : error is  1.25126338584

# %%
Z = np.append(Y,np.reshape(labels, (len(labels),1)), axis = 1)
W = pd.DataFrame(Z, columns = ['Y1','Y2','label'])

#np.savetxt("mnist_three_digits_t_sne.csv", Z, 
#           delimiter=",", 
#           header = "Y1,Y2,label")

W['label'][labels == 1] = 'one'
W['label'][labels == 2] = 'two'
W['label'][labels == 3] = 'three'

W.to_csv('mnist_three_digits_t_sne.csv')

# %%
#Plots the result
plt.scatter(Y[:,0], Y[:,1], c=labels)
#plt.axis('off')
plt.grid(True)
plt.title('Visualizing 2000 MNIST sample using t-SNE')
plt.xlabel('First Component')
plt.ylabel('Second Component')
plt.tick_params(         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',
    right = 'off',
    left = 'off',
    labeltop = 'off', 
    labelleft = 'off', 
    labelright = 'off',
    labelbottom='off') 
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-c2445deddf46> in <module>()
#       1 #Plots the result
# ----> 2 plt.scatter(Y[:,0], Y[:,1], c=labels)
#       3 #plt.axis('off')
#       4 plt.grid(True)
#       5 plt.title('Visualizing 2000 MNIST sample using t-SNE')
#
# NameError: name 'plt' is not defined

# %% [markdown]
# ### Compare with Two Dimensional PCA

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
pca.fit(X.T)

Z = pca.components_.T

#Plots the result
plt.scatter(Z[:,0], Z[:,1], c=labels, cmap=cmap)
#plt.axis('off')
plt.grid(True)
plt.title('Visualizing 2000 MNIST sample using PCA')
plt.xlabel('First Component')
plt.ylabel('Second Component')
plt.tick_params(         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',
    right = 'off',
    left = 'off',
    labeltop = 'off', 
    labelleft = 'off', 
    labelright = 'off',
    labelbottom='off') 
plt.colorbar()
plt.show()

# %% [markdown]
# ### Three Dimensional t-SNE

# %%
#Now with three dimensions
Y3 = tsne(X, 3, 50, 20.0);

# %%
#Plots the result
fig = plt.figure()
ax = Axes3D(fig)
sca = ax.scatter(Y3[:,0], Y3[:,1], Y3[:,2], c=labels, cmap=cmap)
ax.set_title('Visualizing 10000 MNIST sample using t-SNE (3D)')
ax.set_xlabel('First Component')
ax.set_ylabel('Second Component')
ax.set_zlabel('Third Component')
ax.tick_params(         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',
    right = 'off',
    left = 'off',
    labeltop = 'off', 
    labelleft = 'off', 
    labelright = 'off',
    labelbottom='off') 
fig.colorbar(sca, shrink=0.7, aspect=10)

plt.show()

# %% [markdown]
# ### Compare with Three Dimensional PCA

# %%
pca = PCA(n_components=3)
pca.fit(X.T)

Z = pca.components_.T

#Plots the result
fig = plt.figure()
ax = Axes3D(fig)
sca = ax.scatter(Z[:,0], Z[:,1], Z[:,2], c=labels, cmap=cmap)
ax.set_title('Visualizing 10000 MNIST sample using PCA (3D)')
ax.set_xlabel('First Component')
ax.set_ylabel('Second Component')
ax.set_zlabel('Third Component')
ax.tick_params(         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',
    right = 'off',
    left = 'off',
    labeltop = 'off', 
    labelleft = 'off', 
    labelright = 'off',
    labelbottom='off') 
fig.colorbar(sca, shrink=0.7, aspect=10)

plt.show()

# %% [markdown]
# ## Now With Fashion MNIST
# We know apply the same procedure but using the fashion MNIST data set

# %%
#Imports the data and converts it to numpy arrays
mndata = MNIST('../fashion-mnist/data')
X, labels = mndata.load_testing()

#converts to numpy array
X = np.array(X)
labels = np.array(labels)

#subsample_idices = np.random.choice(X.shape[0], 2000)
#X = X[subsample_idices,:]
#labels = labels[subsample_idices]

#Converts to binary the selcted sample

N, D = X.shape

#Declares the cmap for coloring
#COlors
selected_colors = ['red','greenyellow','blue','pink','yellow','orange',
                   'lightcyan','darkolivegreen', 'brown','purple']
cmap = plt.cm.jet
# create the new map
cmap = cmap.from_list('Custom cmap', selected_colors, 10)

# %% [markdown]
# ## Some Examples

# %%
n_row = 3
n_col = 5
for i in range(n_row*n_col):
    ran = np.random.randint(N)
    plt.subplot(n_row, n_col, i+1)
    imshow_noax(X[ran].reshape(28,28), normalize=False)
    plt.title(str(labels[ran]))
plt.show()

# %% [markdown]
# ## Three Dimensional t-SNE

# %%
X = np.around(1-(X/255))
#Now with three dimensions
Y3 = tsne(X, 3, 50, 20.0);
# Out:
# Preprocessing the data using PCA...
# Computing pairwise distances...
# Computing P-values for point  0  of  10000 ...
# Computing P-values for point  500  of  10000 ...
# Computing P-values for point  1000  of  10000 ...
# Computing P-values for point  1500  of  10000 ...
# Computing P-values for point  2000  of  10000 ...
# Computing P-values for point  2500  of  10000 ...
# Computing P-values for point  3000  of  10000 ...
# Computing P-values for point  3500  of  10000 ...
# Computing P-values for point  4000  of  10000 ...
# Computing P-values for point  4500  of  10000 ...
# Computing P-values for point  5000  of  10000 ...
# Computing P-values for point  5500  of  10000 ...
# Computing P-values for point  6000  of  10000 ...
# Computing P-values for point  6500  of  10000 ...
# Computing P-values for point  7000  of  10000 ...
# Computing P-values for point  7500  of  10000 ...
# Computing P-values for point  8000  of  10000 ...
# Computing P-values for point  8500  of  10000 ...
# Computing P-values for point  9000  of  10000 ...
# Computing P-values for point  9500  of  10000 ...
# Mean value of sigma:  1.75574211161
# Iteration  10 : error is  28.8456176402
# Iteration  20 : error is  28.6087540902
# Iteration  30 : error is  25.8377491317
# Iteration  40 : error is  22.8964183201
# Iteration  50 : error is  21.3461904108
# Iteration  60 : error is  20.442608848
# Iteration  70 : error is  19.8915783601
# Iteration  80 : error is  19.5293080983
# Iteration  90 : error is  19.2489222096
# Iteration  100 : error is  19.0192715328
# Iteration  110 : error is  3.05105515393
# Iteration  120 : error is  2.81959479004
# Iteration  130 : error is  2.66984407638
# Iteration  140 : error is  2.55369866294
# Iteration  150 : error is  2.4571925714
# Iteration  160 : error is  2.37468783897
# Iteration  170 : error is  2.3032303066
# Iteration  180 : error is  2.24063329777
# Iteration  190 : error is  2.18525735867
# Iteration  200 : error is  2.13583282193
# Iteration  210 : error is  2.09150126381
# Iteration  220 : error is  2.05149035419
# Iteration  230 : error is  2.01514289671
# Iteration  240 : error is  1.98204786096
# Iteration  250 : error is  1.9517373614
# Iteration  260 : error is  1.92387152737
# Iteration  270 : error is  1.89812985108
# Iteration  280 : error is  1.87425794344
# Iteration  290 : error is  1.85204705115
# Iteration  300 : error is  1.83133037521
# Iteration  310 : error is  1.81194810594
# Iteration  320 : error is  1.79378298339
# Iteration  330 : error is  1.7767232114
# Iteration  340 : error is  1.76066104638
# Iteration  350 : error is  1.74551761227
# Iteration  360 : error is  1.73121835803
# Iteration  370 : error is  1.71769265545
# Iteration  380 : error is  1.7048745102
# Iteration  390 : error is  1.69270609688
# Iteration  400 : error is  1.68113924838
# Iteration  410 : error is  1.670129167
# Iteration  420 : error is  1.65963660553
# Iteration  430 : error is  1.64962614389
# Iteration  440 : error is  1.64004358534
# Iteration  450 : error is  1.63090524405
# Iteration  460 : error is  1.62216864979
# Iteration  470 : error is  1.61380496612
# Iteration  480 : error is  1.60579633275
# Iteration  490 : error is  1.59811518417
# Iteration  500 : error is  1.59074407402
# Iteration  510 : error is  1.58366093084
# Iteration  520 : error is  1.57685198983
# Iteration  530 : error is  1.57029973249
# Iteration  540 : error is  1.5639742382
# Iteration  550 : error is  1.55789525451
# Iteration  560 : error is  1.55203661509
# Iteration  570 : error is  1.54637830767
# Iteration  580 : error is  1.54090012127
# Iteration  590 : error is  1.53563427482
# Iteration  600 : error is  1.53055193821
# Iteration  610 : error is  1.5256410329
# Iteration  620 : error is  1.52088364306
# Iteration  630 : error is  1.51627577272
# Iteration  640 : error is  1.51182278762
# Iteration  650 : error is  1.50750845985
# Iteration  660 : error is  1.50332496029
# Iteration  670 : error is  1.49926430308
# Iteration  680 : error is  1.49532095843
# Iteration  690 : error is  1.49148900253
# Iteration  700 : error is  1.48776256709
# Iteration  710 : error is  1.4841377405
# Iteration  720 : error is  1.48060292268
# Iteration  730 : error is  1.47716028398
# Iteration  740 : error is  1.4738146827
# Iteration  750 : error is  1.47056932697
# Iteration  760 : error is  1.46741671146
# Iteration  770 : error is  1.46434779914
# Iteration  780 : error is  1.46135819928
# Iteration  790 : error is  1.45844173526
# Iteration  800 : error is  1.45560082795
# Iteration  810 : error is  1.4528306794
# Iteration  820 : error is  1.4501263137
# Iteration  830 : error is  1.44748494562
# Iteration  840 : error is  1.44490643962
# Iteration  850 : error is  1.44239035639
# Iteration  860 : error is  1.43993426788
# Iteration  870 : error is  1.43753453484
# Iteration  880 : error is  1.43518757038
# Iteration  890 : error is  1.43288869173
# Iteration  900 : error is  1.43063596387
# Iteration  910 : error is  1.42842078126
# Iteration  920 : error is  1.42623880743
# Iteration  930 : error is  1.42413094214
# Iteration  940 : error is  1.42208236422
# Iteration  950 : error is  1.42007967532
# Iteration  960 : error is  1.41811477124
# Iteration  970 : error is  1.41617976999
# Iteration  980 : error is  1.41430156083
# Iteration  990 : error is  1.41246782438
# Iteration  1000 : error is  1.41067302061

# %% [markdown]
# ### Shows The Coordinates

# %%
#Plots the result
fig = plt.figure()
ax = Axes3D(fig)
sca = ax.scatter(Y3[:,0], Y3[:,1], Y3[:,2], c=labels, cmap=cmap)
ax.set_title('Visualizing 2000 Fashoin MNIST sample using t-SNE (3D)')
ax.set_xlabel('First Component')
ax.set_ylabel('Second Component')
ax.set_zlabel('Third Component')
ax.tick_params(         # changes apply to the x-axis
    which='both',      # both major and minor ticks are affected
    bottom='off',      # ticks along the bottom edge are off
    top='off',
    right = 'off',
    left = 'off',
    labeltop = 'off', 
    labelleft = 'off', 
    labelright = 'off',
    labelbottom='off') 
fig.colorbar(sca, shrink=0.7, aspect=10)

plt.show()

# %% [markdown]
# ### Saves The Coordinates

# %%
head = 'Y1, Y2, Y3'
np.savetxt("tsne_fashion.csv", 
           Y3, 
           delimiter=",", 
           header = head)
